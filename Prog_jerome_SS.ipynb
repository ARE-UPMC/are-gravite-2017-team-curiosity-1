# %%
# Orbites des planètes du système solaire
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

G = 6.67384e-11 # en fonction de metres, secondes, kilogrammes
jour = 3600*24 # en secondes
annee = 365.25*3600*24 # en secondes
UA = 149597870700 # en metres
deux_pi = 2*np.pi


#{Astres : (Diamètres en mètres, Demi-grands axes en mètres, Périodes en jours, Couleurs)}
#{n : (d,a,T,c)}
Astres = {
    "Soleil" : (1.3914e9,0,0, 'yellow'),
    "Mercure" : (4.87946e6, 57.909083e9, 87.9693, 'grey'),
    "Venus" : (1.21036e7, 108.2086e9, 224.701,'orange'),
    "Terre" : (1.27562e7, 149.5980e9, 365.256, 'blue'),
    "Mars" : (6.7924e6, 227.9392e9, 686.986, 'red'),
    "Jupiter" : (1.42984e8, 778.2983e9, 4332.656, 'black'),
    "Saturn" : (1.20596e8, 1429.394e9, 10759.404, 'green'),
    "Uranus" : (5.1118e7, 2875.039e9, 30688.984, 'purple'),
    "Neptune" : (4.9528e7, 4504.450e9, 58707.284, 'blue')
}

Couleurs = ['grey','green','blue','red','orange','black','green','blue']

def theta(T):
    return deux_pi*np.linspace(0, T, 1000)/T

Coord_X = [a*np.cos(theta(T)) for (n,(d,a,T,c)) in Astres.items()]
Coord_Y = [a*np.sin(theta(T)) for (n,(d,a,T,c)) in Astres.items()]

"""def init():
    x_Mercure = Coord_X[1]
    y_Mercure = Coord_Y[1]
    x_Venus = Coord_X[2]
    y_Venus = Coord_Y[2]
    x_Terre = Coord_X[3]
    y_Terre = Coord_Y[3]
    x_Mars = Coord_X[4]
    y_Mars = Coord_Y[4]
    x_Jupiter = Coord_X[5]
    y_Jupiter = Coord_Y[5]
    x_Saturne = Coord_X[6]
    y_Saturne = Coord_Y[6]
    x_Uranus = Coord_X[7]
    y_Uranus = Coord_Y[7]
    x_Neptune = Coord_X[8]
    y_Neptune = Coord_Y[8]"""
    
for (x,y,c,n) in zip(Coord_X, Coord_Y, Couleurs, Astres):
    plt.plot(x, y, color = c, linewidth = 1, linestyle = '-', label = n) 

plt.title('Système solaire avec des orbites circulaires')
plt.legend(loc='upper left')
plt.scatter([0],[0], s = 250, marker=(5,1), color = 'k')
plt.scatter([0],[0], s = 200, marker=(5,1), color = 'y')
plt.show()
# Out:
# C:\Python34\lib\site-packages\ipykernel\__main__.py:30: RuntimeWarning: invalid value encountered in true_divide
# <img src="data:image/png;base64,...">

# %% [markdown]
# Ref :
#
# - Munsell, Kirk; Smith, Harman; Harvey, Samantha (May 28, 2009). ["Mercury: Facts & Figures"](http://solarsystem.nasa.gov/planets/profile.cfm?Object=Mercury&Display=Facts). Solar System Exploration. NASA. Retrieved 2008-04-07.
#
# - Seidelmann, P. Kenneth; Archinal, Brent A.; A'Hearn, Michael F.; et al. (2007). ["Report of the IAU/IAG Working Group on cartographic coordinates and rotational elements: 2006"](https://en.wikipedia.org/wiki/Celestial_Mechanics_and_Dynamical_Astronomy). Celestial Mechanics and Dynamical Astronomy. 98 (3): 155–180.
#
# - [IMCCE](http://www.imcce.fr/langues/fr/grandpublic/systeme/promenade/pages1/19.html)

# %%
# Orbites des planètes du système solaire
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

#{Astres : (Diamètres en mètres, Demi-grands axes en mètres, Périodes en jours, Couleurs)}
#{n : (d,a,T,c)}
Astres = {
    "Mercure" : (4.87946e6, 57.909083e9, 87.9693, 'grey'),
    "Venus" : (1.21036e7, 108.2086e9, 224.701,'green'),
    "Terre" : (1.27562e7, 149.5980e9, 365.256, 'blue'),
    "Mars" : (6.7924e6, 227.9392e9, 686.986, 'red'),
}

Couleurs = ['grey','green','blue','red']

def theta(T):
    return 2*np.pi*np.linspace(0, T, 1000)/T

Coord_X = [a*np.cos(theta(T)) for (n,(d,a,T,c)) in Astres.items()]
Coord_Y = [a*np.sin(theta(T)) for (n,(d,a,T,c)) in Astres.items()]

for (x,y,c,n) in zip(Coord_X, Coord_Y, Couleurs, Astres):
    plt.plot(x, y, color = c, linewidth = 1, linestyle = '-', label = n) 

plt.title('Système solaire avec des orbites circulaires')
plt.legend(loc='upper left')
plt.scatter([0],[0], s = 250, marker=(5,1), color = 'k')
plt.scatter([0],[0], s = 200, marker=(5,1), color = 'y')
plt.show()

# %%
""""#mouvement de Mars dans le référentiel géocentrique
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

def theta(T):
    return 2*np.pi*np.linspace(0, T, 1000)/T

def theta_2(T):
    return 2*np.pi*np.linspace(0, 14000, 1000)/T

#{Astres : (Diamètres en mètres, Demi-grands axes en mètres, Périodes en jours, Couleurs)}
#{n : (d,a,T,c)}
Astres = {
    "Terre" : (1.27562e7, 149.5980e9, 365.256, 'blue'),
    "Mars" : (6.7924e6, 227.9392e9, 686.986, 'red'),
}

Couleurs = ['red']

Coord_X = [a*np.cos(theta(T)) for (n,(d,a,T,c)) in Astres.items()]
Coord_Y = [a*np.sin(theta(T)) for (n,(d,a,T,c)) in Astres.items()]

#Listes des coordonnées dans le référentiel géocentrique
Coord_X_2=[a*np.cos(theta_2(T)) for (n,(d,a,T,c)) in Astres.items()]
Coord_Y_2=[a*np.sin(theta_2(T)) for (n,(d,a,T,c)) in Astres.items()]

x_2_Terre =Coord_X_2[0]
y_2_Terre =Coord_Y_2[0]


#Tracé des trajectoires dans le référentiel géocentrique
for (x,y,c,n) in zip(Coord_X_2, Coord_Y_2, Couleurs, Astres):
    plt.plot(x-x_2_Terre,y-y_2_Terre,color=c,linewidth=1,linestyle='-',label=n)
plt.axis("equal")
plt.title("Trajectoire de Mars dans le référentiel géocentrique")
plt.legend(loc='upper left')
plt.scatter([0],[0], s = 250, marker=(5,1), color = 'k')
plt.scatter([0],[0], s = 200, marker=(5,1), color = 'y')
plt.show""""
# Out:
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>

# %%
""""import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

fig = plt.figure()
ax = plt.axes(xlim=(-3, 3), ylim=(-3, 3))
fig.set_dpi(100)

terre = plt.Circle((5, -5), 1, fc='b')
mars = plt.Circle((5, -5), 0.53, fc='r')

    
def init():
    terre.center = (5, 5)
    ax.add_patch(terre)
    mars.center = (5, 5)
    ax.add_patch(mars)
    return terre, mars,

def animate(i):
    x, y = terre.center
    x = 0 + 1 * np.sin(np.radians(i)*2*np.pi/1)
    y = 0 + 1 * np.cos(np.radians(i)*2*np.pi/1)
    terre.center = (x, y)
    v, w = mars.center
    v = 0 + 1.52 * np.sin(np.radians(i)*2*np.pi/1.88)
    w = 0 + 1.52 * np.cos(np.radians(i)*2*np.pi/1.88)
    mars.center = (v, w)
    return terre, mars,


anim = animation.FuncAnimation(fig, animate, 
                               init_func=init, 
                               frames=235, 
                               interval=20,
                               blit=True)

plt.title('Mars et la Terre')
plt.legend(loc='upper left')
plt.show()"""
# Out:
# <img src="data:image/png;base64,...">

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

fig = plt.figure()
ax = plt.axes(xlim=(-20,20), ylim=(-20, 20))
fig.set_dpi(100)
#fig.set_size_inches(10, 10)

terre = plt.Circle((5, -5), 1, fc='b')
mars = plt.Circle((5, -5), 0.53, fc='r')

    
def init():
    terre.center = (0, 0)
    ax.add_patch(terre)
    mars.center = (0, 0)
    ax.add_patch(mars)
    return terre, mars,

plt.cla() 

def animate(i):
    x, y = terre.center
    x = 0 + 10 * np.sin(np.radians(i)*2*np.pi/1)
    y = 0 + np.sqrt(10 - (10*0.01671022)**2) * np.cos(np.radians(i)*2*np.pi/1)
    terre.center = (x, y)
    v, w = mars.center
    v = 0 + 15.2 * np.sin(np.radians(i)*2*np.pi/1.88)
    w = 0 + np.sqrt(15.2**2-(15.2*0.09341233)**2) * np.cos(np.radians(i)*2*np.pi/1.88)
    mars.center = (v, w)
    return terre, mars,


anim = animation.FuncAnimation(fig, animate, 
                               init_func=init, 
                               frames=235, 
                               interval=20,
                               blit=True)

plt.title('Mars et la Terre')
plt.legend(loc='upper left')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# Orbites des planètes du système solaire
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

#{Astres : (Diamètres en mètres, Demi-grands axes en mètres, Périodes en jours, Couleurs)}
#{n : (d,a,T,c)}
Astres = {
    "Mercure" : (4.87946e6, 57.909083e9, 87.9693, 'grey'),
    "Venus" : (1.21036e7, 108.2086e9, 224.701,'green'),
    "Terre" : (1.27562e7, 149.5980e9, 365.256, 'blue'),
    "Mars" : (6.7924e6, 227.9392e9, 686.986, 'red'),
}

Couleurs = ['grey','green','blue','red']

def theta(T):
    return 2*np.pi*np.linspace(0, T, 1000)/T

Coord_X = [a*np.cos(theta(T)) for (n,(d,a,T,c)) in Astres.items()]
Coord_Y = [a*np.sin(theta(T)) for (n,(d,a,T,c)) in Astres.items()]

for (x,y,c,n) in zip(Coord_X, Coord_Y, Couleurs, Astres):
    plt.plot(x, y, color = c, linewidth = 1, linestyle = '-', label = n) 

plt.title('Système solaire avec des orbites circulaires')
plt.legend(loc='upper left')
plt.scatter([0],[0], s = 250, marker=(5,1), color = 'k')
plt.scatter([0],[0], s = 200, marker=(5,1), color = 'y')
#plt.show()


#line, = ax.plot([], [], color='k')

Mercure = plt.Circle((0, 0), 4.87946e6, fc='g')
Venus = plt.Circle((0, 0), 1.21036e7, fc='b')
Terre = plt.Circle((0, 0), 1.27562e7, fc='k')
Mars = plt.Circle((0, 0), 6.7924e6, fc='b')


def init():
    Mercure.center = (0, 0)
    Venus.center = (0, 0)
    Terre.center = (0, 0)
    Mars.center = (0, 0)
    ax.add_patch(Mercure)
    ax.add_patch(Venus)
    ax.add_patch(Terre)
    ax.add_patch(Mars)
    return Mercure, Venus, Terre, Mars,
"""
def update(num, x, y, line):
    #Coord_X = [149e9*np.cos(theta(365))]
    #Coord_Y = [149e9*np.sin(theta(365))]
    #line.set_data(Coord_X[:num], Coord_Y[:num])
    x_Mercure, y_Mercure = Mercure.center
    x_Mercure = 0 + 157.909083e9 * np.sin(np.radians(i)*2*np.pi/87.9693)
    y_Mercure = 0 + np.sqrt(57.909083e18 - (57.909083e9*0.20563069)**2) * np.cos(np.radians(i)*2*np.pi/87.9693)
    Mercure.center = (x_Mercure, y_Mercure)
    x_Venus, y_Venus = Venus.center
    x_Venus = 0 + 108.2086e9 * np.sin(np.radians(i)*2*np.pi/224.701)
    y_Venus = 0 + np.sqrt(108.2086e18 - (108.2086e9*0.0068)**2) * np.cos(np.radians(i)*2*np.pi/224.701)
    Venus.center = (x_Venus, y_Venus)
    x_Terre, y_Terre = Terre.center
    x_Terre = 0 + 149.5980e9 * np.sin(np.radians(i)*2*np.pi/365.256)
    y_Terre = 0 + np.sqrt(149.5980e18 - (149.5980e9*0.01671022)**2) * np.cos(np.radians(i)*2*np.pi/365.256)
    Terre.center = (x_Terre, y_Terre)
    x_Mars, y_Mars = Mars.center
    x_Mars = 0 + 227.9392e9 * np.sin(np.radians(i)*2*np.pi/686.986)
    y_Mars = 0 + np.sqrt(227.9392e18 - (10*0.09341233)**2) * np.cos(np.radians(i)*2*np.pi/686.986)
    Mars.center = (x_Mars, y_Mars)
    return Mercure, Venus, Terre, Mars,"""

def update(num, x, y, line):
    #Coord_X = [149e9*np.cos(theta(365))]
    #Coord_Y = [149e9*np.sin(theta(365))]
    #line.set_data(Coord_X[:num], Coord_Y[:num])
    x_Mercure, y_Mercure = Mercure.center
    x_Mercure = 0 + 57.909083e9 * np.sin(np.radians(i)*2*np.pi/87.9693)
    y_Mercure = 0 + 57.909083e9 * np.cos(np.radians(i)*2*np.pi/87.9693)
    Mercure.center = (x_Mercure, y_Mercure)
    x_Venus, y_Venus = Venus.center
    x_Venus = 0 + 108.2086e9 * np.sin(np.radians(i)*2*np.pi/224.701)
    y_Venus = 0 + 108.2086e9 * np.cos(np.radians(i)*2*np.pi/224.701)
    Venus.center = (x_Venus, y_Venus)
    x_Terre, y_Terre = Terre.center
    x_Terre = 0 + 149.5980e9 * np.sin(np.radians(i)*2*np.pi/365.256)
    y_Terre = 0 + 149.5980e9 * np.cos(np.radians(i)*2*np.pi/365.256)
    Terre.center = (x_Terre, y_Terre)
    x_Mars, y_Mars = Mars.center
    x_Mars = 0 + 227.9392e9 * np.sin(np.radians(i)*2*np.pi/686.986)
    y_Mars = 0 + 227.9392e9 * np.cos(np.radians(i)*2*np.pi/686.986)
    Mars.center = (x_Mars, y_Mars)
    return Mercure, Venus, Terre, Mars,

#ani = animation.FuncAnimation(fig, update, len(Coord_X), fargs=[Coord_X, Coord_Y, line], interval=25, blit=True)
anim = animation.FuncAnimation(fig, animate, 
                               init_func=init, 
                               frames=235, 
                               interval=20,
                               blit=True)
# Out:
# <div id='40e892b2-4fd6-4082-aa84-de6a71d2068b'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-5ed7f4955662> in <module>()
#     103                                frames=235,
#     104                                interval=20,
# --> 105                                blit=True)
#     106
#
# C:\Python34\lib\site-packages\matplotlib\animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, **kwargs)
#    1065         self._save_seq = []
#    1066
# -> 1067         TimedAnimation.__init__(self, fig, **kwargs)
#    1068
#    1069         # Need to reset the saved seq, since right now it will contain data
#
# C:\Python34\lib\site-packages\matplotlib\animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#     911
#     912         Animation.__init__(self, fig, event_source=event_source,
# --> 913                            *args, **kwargs)
#     914
#     915     def _step(self, *args):
#
# C:\Python34\lib\site-packages\matplotlib\animation.py in __init__(self, fig, event_source, blit)
#     589
#     590         # Clear the initial frame
# --> 591         self._init_draw()
#     592
#     593         # Instead of starting the event source now, we connect to the figure's
#
# C:\Python34\lib\site-packages\matplotlib\animation.py in _init_draw(self)
#    1092             self._draw_frame(next(self.new_frame_seq()))
#    1093         else:
# -> 1094             self._drawn_artists = self._init_func()
#    1095
#    1096     def _draw_frame(self, framedata):
#
# <ipython-input-21-5ed7f4955662> in init()
#      44
#      45 def init():
# ---> 46     Mercure.center = (0, 0)
#      47     Venus.center = (0, 0)
#      48     Terre.center = (0, 0)
#
# AttributeError: 'list' object has no attribute 'center'
